# %%
# pip install swifter

# %%
# # Install spaCy (if you haven't already)
# !pip install spacy

# # Download the small English model
# !python -m spacy download en_core_web_sm
# Out:
# ...
#   Obtaining dependency information for spacy from https://files.pythonhosted.org/packages/a1/63/94edfc9b8cc7c5a96143a1d46b3af6abd930c2f66508b7e3afb1839b934e/spacy-3.8.9-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for spacy-legacy<3.1.0,>=3.0.11 from https://files.pythonhosted.org/packages/c3/55/12e842c70ff8828e34e543a2c7176dac4da006ca6901c9e8b43efab8bc6b/spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for spacy-loggers<2.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/33/78/d1a1a026ef3af911159398c939b1509d5c36fe524c7b644f34a5146c4e16/spacy_loggers-1.0.5-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for murmurhash<1.1.0,>=0.28.0 from https://files.pythonhosted.org/packages/82/ed/812103a7f353eba2d83655b08205e13a38c93b4db0692f94756e1eb44516/murmurhash-1.0.15-cp311-cp311-win_amd64.whl.metadata
# ...

# %%
# !pip install owlready2
# Out:
# ...
#      ---------------------------------------- 0.0/27.3 MB ? eta -:--:--
#      --------------------------------------- 0.0/27.3 MB 640.0 kB/s eta 0:00:43
#      --------------------------------------- 0.0/27.3 MB 435.7 kB/s eta 0:01:03
#      --------------------------------------- 0.0/27.3 MB 435.7 kB/s eta 0:01:03
#      --------------------------------------- 0.0/27.3 MB 435.7 kB/s eta 0:01:03
#      --------------------------------------- 0.0/27.3 MB 435.7 kB/s eta 0:01:03
#      --------------------------------------- 0.0/27.3 MB 435.7 kB/s eta 0:01:03
#      --------------------------------------- 0.0/27.3 MB 435.7 kB/s eta 0:01:03
#      --------------------------------------- 0.0/27.3 MB 435.7 kB/s eta 0:01:03
#      --------------------------------------- 0.0/27.3 MB 435.7 kB/s eta 0:01:03
#      --------------------------------------- 0.0/27.3 MB 435.7 kB/s eta 0:01:03
#      --------------------------------------- 0.0/27.3 MB 435.7 kB/s eta 0:01:03
# ...

# %%
# !pip install vaderSentiment
# Out:
# ...
#   Obtaining dependency information for vaderSentiment from https://files.pythonhosted.org/packages/76/fc/310e16254683c1ed35eeb97386986d6c00bc29df17ce280aed64d55537e9/vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/126.0 kB ? eta -:--:--
#    ------ -------------------------------- 20.5/126.0 kB 640.0 kB/s eta 0:00:01
#    --------- ----------------------------- 30.7/126.0 kB 640.0 kB/s eta 0:00:01
#    --------- ----------------------------- 30.7/126.0 kB 640.0 kB/s eta 0:00:01
#    ------------ -------------------------- 41.0/126.0 kB 217.9 kB/s eta 0:00:01
#    ------------------------- ------------- 81.9/126.0 kB 351.4 kB/s eta 0:00:01
#    ---------------------------- ---------- 92.2/126.0 kB 348.6 kB/s eta 0:00:01
#    ---------------------------- ---------- 92.2/126.0 kB 348.6 kB/s eta 0:00:01
#    -------------------------------------- 126.0/126.0 kB 321.4 kB/s eta 0:00:00
# ...

# %%
# !pip install graphviz
# Out:
# ...
#   Obtaining dependency information for graphviz from https://files.pythonhosted.org/packages/91/4c/e0ce1ef95d4000ebc1c11801f9b944fa5910ecc15b5e351865763d8657f8/graphviz-0.21-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/47.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/47.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/47.3 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/47.3 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/47.3 kB ? eta -:--:--
#    ----------------- ---------------------- 20.5/47.3 kB 108.9 kB/s eta 0:00:01
#    ----------------- ---------------------- 20.5/47.3 kB 108.9 kB/s eta 0:00:01
#    ----------------- ---------------------- 20.5/47.3 kB 108.9 kB/s eta 0:00:01
#    ------------------------- -------------- 30.7/47.3 kB 87.1 kB/s eta 0:00:01
#    ------------------------- -------------- 30.7/47.3 kB 87.1 kB/s eta 0:00:01
# ...

# %%
import pandas as pd
import json

file_path = 'hotel_reviews.json'
mini_file_path = 'mini_hotel_reviews.json'

data = []
max_records = 10000

print(f"Reading first {max_records} records from file: {file_path}")
print("This may take a moment...")

with open(file_path, 'r', encoding='utf-8') as f:
    for i, line in enumerate(f):
        if i >= max_records:
            break
        try:
            data.append(json.loads(line))
        except json.JSONDecodeError:
            pass 

print(f"Successfully loaded {len(data)} valid reviews.")

# Save the mini dataset to a new file
print(f"\nSaving to {mini_file_path}...")
with open(mini_file_path, 'w', encoding='utf-8') as f:
    for record in data:
        f.write(json.dumps(record) + '\n')

print(f"Mini dataset saved to {mini_file_path}!")

# Now read from the mini file for future work
print(f"\nReading from mini file: {mini_file_path}")
mini_data = []

with open(mini_file_path, 'r', encoding='utf-8') as f:
    for line in f:
        try:
            mini_data.append(json.loads(line))
        except json.JSONDecodeError:
            pass

df = pd.DataFrame(mini_data)

print(f"Successfully loaded {len(df)} records from mini file!")
print("\nDataFrame created successfully!")
print(f"DataFrame shape: {df.shape}")
# Out:
# Reading first 10000 records from file: hotel_reviews.json
# This may take a moment...
# Successfully loaded 10000 valid reviews.
#
# Saving to mini_hotel_reviews.json...
# Mini dataset saved to mini_hotel_reviews.json!
#
# Reading from mini file: mini_hotel_reviews.json
# Successfully loaded 10000 records from mini file!
#
# DataFrame created successfully!
# DataFrame shape: (10000, 9)

# %%
df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0    3.0       0      0     0
# 1    5.0       1      0     1
# 2    3.0       0      0     0
# 3    5.0       1      0     1
# 4    4.0       1      0     1
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   review_id    10000 non-null  object
#  1   user_id      10000 non-null  object
#  2   business_id  10000 non-null  object
#  3   stars        10000 non-null  float64
#  4   useful       10000 non-null  int64
#  5   funny        10000 non-null  int64
#  6   cool         10000 non-null  int64
#  7   text         10000 non-null  object
#  8   date         10000 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 703.3+ KB

# %%
import re
import nltk
from nltk.tokenize import word_tokenize

# nltk.download('stopwords')
# nltk.download('punkt')

/
def preprocess_text(text):
    """
    Preprocess text by cleaning, tokenizing, and removing custom stopwords.
    """
    if not isinstance(text, str):
        return [] 

    # Convert to lowercase
    text = text.lower()
    # Remove URLs and HTML tags
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'<.*?>', '', text)
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    # Tokenize
    tokens = word_tokenize(text)
    
    return tokens

# %%
import spacy
# Load the model. We only disable the parser to speed it up.
# We NEED the 'tagger' for POS and 'ner' for NER.
nlp = spacy.load("en_core_web_sm", disable=["parser"])

# %%
def replace_with_pos(text):
    """
    Finds the Part-of-Speech tag for each token and returns a string of tags.
    Example: "Good food!" -> "ADJ NOUN PUNCT"
    """
    doc = nlp(text)
    
    # We use token.pos_ which gives the universal tag (e.g., "VERB", "NOUN", "ADJ")
    # This is better for features than the highly detailed "token.tag_"
    return " ".join([token.pos_ for token in doc])

# (You can also add the 'replace_entities' function from my previous answer here)
def replace_entities(text):
    doc = nlp(text)
    new_text = list(text)
    for ent in reversed(doc.ents):
        new_text[ent.start_char:ent.end_char] = ent.label_
    return "".join(new_text)

# %%
import swifter

# --- NEW: Apply NER and POS Functions FIRST ---
print("Applying NER to raw text...")
df['ner_text'] = df['text'].swifter.apply(replace_entities)

print("Applying POS tagging to raw text...")
df['pos_text'] = df['text'].swifter.apply(replace_with_pos)
# --- END NEW ---


# --- Now, create clean tokens from ALL text versions ---
print("Creating 'clean_tokens' (from original text)...")
df['clean_tokens'] = df['text'].swifter.apply(preprocess_text)

print("Creating 'clean_tokens_ner' (from NER text)...")
df['clean_tokens_ner'] = df['ner_text'].swifter.apply(preprocess_text)

print("Creating 'clean_tokens_pos' (from POS text)...")
df['clean_tokens_pos'] = df['pos_text'].swifter.apply(preprocess_text)
# Out:
# Applying NER to raw text...
# Pandas Apply:   0%|          | 0/10000 [00:00<?, ?it/s]
# Applying POS tagging to raw text...
# Pandas Apply:   0%|          | 0/10000 [00:00<?, ?it/s]
# Creating 'clean_tokens' (from original text)...
# Pandas Apply:   0%|          | 0/10000 [00:00<?, ?it/s]
# Creating 'clean_tokens_ner' (from NER text)...
# Pandas Apply:   0%|          | 0/10000 [00:00<?, ?it/s]
# Creating 'clean_tokens_pos' (from POS text)...
# Pandas Apply:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
df[['text', 'clean_tokens']].head(10)
# Out:
#                                                 text  \
# 0  If you decide to eat here, just be aware it is...
# 1  I've taken a lot of spin classes over the year...
# 2  Family diner. Had the buffet. Eclectic assortm...
# 3  Wow!  Yummy, different,  delicious.   Our favo...
# 4  Cute interior and owner (?) gave us tour of up...
# 5  I am a long term frequent customer of this est...
# 6  Loved this tour! I grabbed a groupon and the p...
# 7  Amazingly amazing wings and homemade bleu chee...
# 8  This easter instead of going to Lopez Lake we ...
# 9  Had a party of 6 here for hibachi. Our waitres...
#
#                                         clean_tokens
# 0  [decide, eat, aware, going, take, hours, begin...
# 1  [ive, taken, lot, spin, classes, years, nothin...
# 2  [family, diner, buffet, eclectic, assortment, ...
# 3  [wow, yummy, different, delicious, favorite, l...
# 4  [cute, interior, owner, gave, us, tour, upcomi...
# 5  [long, term, frequent, customer, establishment...
# ...

# %%
from nltk.util import ngrams

def generate_ngrams(tokens, n):
    """
    Generates n-grams from a list of tokens and joins them into strings.
    """
    # Generate the n-grams as tuples
    n_grams = ngrams(tokens, n)
    # Join the words in each n-gram tuple with an underscore
    return ["_".join(gram) for gram in n_grams]

# %%
# Create a new column for bigrams (n=2)
df['bigrams'] = df['clean_tokens'].swifter.apply(lambda tokens: generate_ngrams(tokens, 2))

# Create a new column for trigrams (n=3)
df['trigrams'] = df['clean_tokens'].swifter.apply(lambda tokens: generate_ngrams(tokens, 3))

# Display the result to see your new n-gram columns
df[['clean_tokens', 'bigrams', 'trigrams']].head()
# Out:
# ...
# Pandas Apply:   0%|          | 0/10000 [00:00<?, ?it/s]
#                                         clean_tokens  \
# 0  [decide, eat, aware, going, take, hours, begin...
# 1  [ive, taken, lot, spin, classes, years, nothin...
# 2  [family, diner, buffet, eclectic, assortment, ...
# 3  [wow, yummy, different, delicious, favorite, l...
# 4  [cute, interior, owner, gave, us, tour, upcomi...
#
#                                              bigrams  \
# 0  [decide_eat, eat_aware, aware_going, going_tak...
# 1  [ive_taken, taken_lot, lot_spin, spin_classes,...
# 2  [family_diner, diner_buffet, buffet_eclectic, ...
# 3  [wow_yummy, yummy_different, different_delicio...
# 4  [cute_interior, interior_owner, owner_gave, ga...
#
#                                             trigrams
# 0  [decide_eat_aware, eat_aware_going, aware_goin...
# 1  [ive_taken_lot, taken_lot_spin, lot_spin_class...
# 2  [family_diner_buffet, diner_buffet_eclectic, b...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# Set a nice style for the plots
sns.set_style('whitegrid')

# %%
# Flatten the list of tokens into a single list
all_unigrams = [token for sublist in df['clean_tokens'] for token in sublist]

# Count the frequency of each unigram
unigram_counts = Counter(all_unigrams)

# Get the 10 most common unigrams
top_10_unigrams = unigram_counts.most_common(10)

# Create a DataFrame for plotting
df_unigrams = pd.DataFrame(top_10_unigrams, columns=['unigram', 'frequency'])

# Plot the results
plt.figure(figsize=(12, 8))
sns.barplot(x='frequency', y='unigram', data=df_unigrams, palette='viridis')
plt.title('Top 10 Most Frequent Unigrams')
plt.xlabel('Frequency')
plt.ylabel('Unigram')
plt.show()

# %%
# Flatten the list of bigrams into a single list
all_bigrams = [bigram for sublist in df['bigrams'] for bigram in sublist]

# Count the frequency of each bigram
bigram_counts = Counter(all_bigrams)

# Get the 10 most common bigrams
top_10_bigrams = bigram_counts.most_common(10)

# Create a DataFrame for plotting
df_bigrams = pd.DataFrame(top_10_bigrams, columns=['bigram', 'frequency'])

# Plot the results
plt.figure(figsize=(12, 8))
sns.barplot(x='frequency', y='bigram', data=df_bigrams, palette='plasma')
plt.title('Top 10 Most Frequent Bigrams')
plt.xlabel('Frequency')
plt.ylabel('Bigram')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bigrams'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
# ...

# %%
# Flatten the list of trigrams into a single list
all_trigrams = [trigram for sublist in df['trigrams'] for trigram in sublist]

# Count the frequency of each trigram
trigram_counts = Counter(all_trigrams)

# Get the 10 most common trigrams
top_10_trigrams = trigram_counts.most_common(10)

# Create a DataFrame for plotting
df_trigrams = pd.DataFrame(top_10_trigrams, columns=['trigram', 'frequency'])

# Plot the results
plt.figure(figsize=(12, 8))
sns.barplot(x='frequency', y='trigram', data=df_trigrams, palette='magma')
plt.title('Top 10 Most Frequent Trigrams')
plt.xlabel('Frequency')
plt.ylabel('Trigram')
plt.show()

# %%
from nltk.stem import PorterStemmer

# Initialize the stemmer
porter = PorterStemmer()

# %%
# This is the corrected code
df['porter_stem_tokens'] = df['clean_tokens'].swifter.apply(lambda token_list: [porter.stem(token) for token in token_list])
# Display the result to check
df[['clean_tokens', 'porter_stem_tokens']].head()
# Out:
# Pandas Apply:   0%|          | 0/10000 [00:00<?, ?it/s]
#                                         clean_tokens  \
# 0  [if, you, decide, to, eat, here, ,, just, be, ...
# 1  [i, 've, taken, a, lot, of, spin, classes, ove...
# 2  [family, diner, ., had, the, buffet, ., eclect...
# 3  [wow, !, yummy, ,, different, ,, delicious, .,...
# 4  [cute, interior, and, owner, (, ?, ), gave, us...
#
#                                   porter_stem_tokens
# 0  [if, you, decid, to, eat, here, ,, just, be, a...
# 1  [i, 've, taken, a, lot, of, spin, class, over,...
# 2  [famili, diner, ., had, the, buffet, ., eclect...
# 3  [wow, !, yummi, ,, differ, ,, delici, ., our, ...
# 4  [cute, interior, and, owner, (, ?, ), gave, us...

# %%
from nltk.stem import SnowballStemmer

# Initialize the stemmer for English
snowball = SnowballStemmer('english')

# %%
# This is the corrected code
df['snowball_stem_tokens'] = df['clean_tokens'].swifter.apply(lambda token_list: [snowball.stem(token) for token in token_list])
# Display the result to check
df[['clean_tokens', 'snowball_stem_tokens']].head()
# Out:
# Pandas Apply:   0%|          | 0/10000 [00:00<?, ?it/s]
#                                         clean_tokens  \
# 0  [if, you, decide, to, eat, here, ,, just, be, ...
# 1  [i, 've, taken, a, lot, of, spin, classes, ove...
# 2  [family, diner, ., had, the, buffet, ., eclect...
# 3  [wow, !, yummy, ,, different, ,, delicious, .,...
# 4  [cute, interior, and, owner, (, ?, ), gave, us...
#
#                                 snowball_stem_tokens
# 0  [if, you, decid, to, eat, here, ,, just, be, a...
# 1  [i, ve, taken, a, lot, of, spin, class, over, ...
# 2  [famili, diner, ., had, the, buffet, ., eclect...
# 3  [wow, !, yummi, ,, differ, ,, delici, ., our, ...
# 4  [cute, interior, and, owner, (, ?, ), gave, us...

# %%
from nltk.stem import LancasterStemmer

# Initialize the stemmer
lancaster = LancasterStemmer()

# %%
# This is the corrected code
df['lancaster_stem_tokens'] = df['clean_tokens'].swifter.apply(lambda token_list: [lancaster.stem(token) for token in token_list])
# Display the result to check
df[['clean_tokens', 'lancaster_stem_tokens']].head()
# Out:
# Pandas Apply:   0%|          | 0/10000 [00:00<?, ?it/s]
#                                         clean_tokens  \
# 0  [if, you, decide, to, eat, here, ,, just, be, ...
# 1  [i, 've, taken, a, lot, of, spin, classes, ove...
# 2  [family, diner, ., had, the, buffet, ., eclect...
# 3  [wow, !, yummy, ,, different, ,, delicious, .,...
# 4  [cute, interior, and, owner, (, ?, ), gave, us...
#
#                                lancaster_stem_tokens
# 0  [if, you, decid, to, eat, her, ,, just, be, aw...
# 1  [i, 've, tak, a, lot, of, spin, class, ov, the...
# 2  [famy, din, ., had, the, buffet, ., eclect, as...
# 3  [wow, !, yummy, ,, diff, ,, delicy, ., our, fa...
# 4  [cut, intery, and, own, (, ?, ), gav, us, tour...

# %%
# Create the target variable based on rating
df['class'] = df['stars'].apply(lambda x: 1 if x >= 4 else 0)

# Display the distribution of classes
print("Class distribution:")
print(df['class'].value_counts())
print(f"\nPercentage of positive reviews (class=1): {df['class'].mean():.2%}")
# Out:
# Class distribution:
# class
# 1    7019
# 0    2981
# Name: count, dtype: int64
#
# Percentage of positive reviews (class=1): 70.19%

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

def vectorize_all_datasets(df, token_columns, ngram_ranges):
    """
    Vectorizes and stores all combinations of tokens and n-grams.
    
    Args:
        df: Your main DataFrame
        token_columns: List of token column names (e.g., ['clean_tokens', 'porter_stem_tokens'])
        ngram_ranges: List of tuples for n-grams (e.g., [(1, 1), (1, 2)])
        
    Returns:
        A dictionary where keys are dataset names and values are 
        tuples of (X_train, X_test, y_train, y_test)
    """
    
    print("--- Starting: Vectorizing all feature sets ---")
    
    vectorized_datasets = {} 

    for token_col in token_columns:
        for ngrams in ngram_ranges:
            
            # Prepare X and y
            X = df[token_col].apply(lambda tokens: ' '.join(tokens) if isinstance(tokens, list) else '')
            y = df['class']
            
            # Split
            X_train, X_test, y_train, y_test = train_test_split(
                X, y, test_size=0.3, random_state=42, stratify=y
            )
            
            # Vectorize
            vectorizer = TfidfVectorizer(
                max_features=5000, min_df=5, max_df=0.7, ngram_range=ngrams
            )
            X_train_tfidf = vectorizer.fit_transform(X_train)
            X_test_tfidf = vectorizer.transform(X_test)
            
            # Store the vectorized data
            dataset_name = f"{token_col}__{ngrams}"
            vectorized_datasets[dataset_name] = (X_train_tfidf, X_test_tfidf, y_train, y_test)
            print(f"Stored: {dataset_name}")

    print("\n--- Complete: All datasets are vectorized and stored. ---")
    return vectorized_datasets

# %%
from sklearn.metrics import classification_report
import time
from sklearn.model_selection import GridSearchCV

def run_model_experiments_with_gridsearch(vectorized_datasets, models_config):
    """
    Trains and evaluates multiple models on the stored vectorized datasets,
    with optional GridSearchCV for each model.
    
    Parameters:
    - vectorized_datasets: Dictionary of datasets
    - models_config: Dictionary mapping model names to tuples of (model_object, param_grid)
      where param_grid can be:
        - A dictionary of parameters for GridSearchCV
        - None to train the model without GridSearch
    """
    
    print("\n--- Starting: Running all model experiments with GridSearch ---")
    
    # These are the labels for your report, from your 'class' column
    target_names = ['Negative (0)', 'Positive (1)']
    
    # Loop through each stored dataset
    for dataset_name, (X_train, X_test, y_train, y_test) in vectorized_datasets.items():
        
        # Loop through each model configuration
        for model_name, (model, param_grid) in models_config.items():
            
            print("\n" + "="*80)
            print(f"MODEL: {model_name}   |   DATASET: {dataset_name}")
            print("="*80)
            
            start_time = time.time()
            
            if param_grid is not None:
                # --- GridSearchCV for this model ---
                print("Using GridSearchCV for hyperparameter tuning...")
                
                # Perform GridSearchCV
                grid_search = GridSearchCV(
                    model,
                    param_grid,
                    cv=5,
                    scoring='f1_weighted',
                    n_jobs=-1,
                    verbose=1
                )
                
                # Fit GridSearch
                grid_search.fit(X_train, y_train)
                
                # Get best model
                best_model = grid_search.best_estimator_
                
                # Predict with best model
                y_pred_train = best_model.predict(X_train)
                y_pred_test = best_model.predict(X_test)
                
                end_time = time.time()
                
                # --- Report - TRAINING Data ---
                print("\n--- 1. TRAINING SET Evaluation ---")
                print(classification_report(y_train, y_pred_train, target_names=target_names, digits=4, zero_division=0))

                # --- Report - TEST Data ---
                print("\n--- 2. TEST SET Evaluation ---")
                print(classification_report(y_test, y_pred_test, target_names=target_names, digits=4, zero_division=0))
                
                # --- GridSearch Results ---
                print("\n--- 3. GRID SEARCH RESULTS ---")
                print(f"Best parameters: {grid_search.best_params_}")
                print(f"Best cross-validation score: {grid_search.best_score_:.4f}")
                print(f"GridSearch Time: {end_time - start_time:.2f} seconds")
                
            else:
                # --- Regular model training (no GridSearch) ---
                print("Training model without GridSearch...")
                
                # Train
                model.fit(X_train, y_train)
                
                # Predict
                y_pred_train = model.predict(X_train)
                y_pred_test = model.predict(X_test)
                
                end_time = time.time()
                
                # --- Report - TRAINING Data ---
                print("\n--- 1. TRAINING SET Evaluation ---")
                print(classification_report(y_train, y_pred_train, target_names=target_names, digits=4))
                
                # --- Report - TEST Data ---
                print("\n--- 2. TEST SET Evaluation ---")
                print(classification_report(y_test, y_pred_test, target_names=target_names, digits=4))
                
                print(f"\nTraining & Prediction Time: {end_time - start_time:.2f} seconds")
            
            print("="*80 + "\n")

    print("\n--- Complete: All experiments finished. ---")

# %%
# --- MODIFY THIS LINE ---
token_columns = ['clean_tokens', 
                 'clean_tokens_ner',
                 'clean_tokens_pos',
                 'porter_stem_tokens', 
                 'snowball_stem_tokens', 
                 'lancaster_stem_tokens']
# --- END MODIFY ---

ngram_ranges = [(1, 1), (2, 2), (3, 3)]

vectorized_data_store = vectorize_all_datasets(df, token_columns, ngram_ranges)
# Out:
# --- Starting: Vectorizing all feature sets ---
# Stored: clean_tokens__(1, 1)
# Stored: clean_tokens__(2, 2)
# Stored: clean_tokens__(3, 3)
# Stored: clean_tokens_ner__(1, 1)
# Stored: clean_tokens_ner__(2, 2)
# Stored: clean_tokens_ner__(3, 3)
# Stored: clean_tokens_pos__(1, 1)
# Stored: clean_tokens_pos__(2, 2)
# Stored: clean_tokens_pos__(3, 3)
# Stored: porter_stem_tokens__(1, 1)
# Stored: porter_stem_tokens__(2, 2)
# Stored: porter_stem_tokens__(3, 3)
# Stored: snowball_stem_tokens__(1, 1)
# Stored: snowball_stem_tokens__(2, 2)
# Stored: snowball_stem_tokens__(3, 3)
# Stored: lancaster_stem_tokens__(1, 1)
# Stored: lancaster_stem_tokens__(2, 2)
# Stored: lancaster_stem_tokens__(3, 3)
#
# --- Complete: All datasets are vectorized and stored. ---

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Define parameter grids for different models
dt_param_grid = {
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5],
    'criterion': ['gini', 'entropy'],
    'max_features': ['sqrt', 'log2', None]
}

# Define models configuration
models_config = {
    # Models with GridSearch
    'DecisionTree_GridSearch': (
        DecisionTreeClassifier(random_state=42), 
        dt_param_grid
    ),
}

# Run experiments with all models and datasets
print("\nStarting model experiments with flexible GridSearch...")
run_model_experiments_with_gridsearch(vectorized_data_store, models_config)
# Out:
# Starting model experiments with flexible GridSearch...
#
# --- Starting: Running all model experiments with GridSearch ---
#
# ...
# MODEL: DecisionTree_GridSearch   |   DATASET: clean_tokens__(1, 1)
# ...
# Using GridSearchCV for hyperparameter tuning...
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
#
# --- 1. TRAINING SET Evaluation ---
#               precision    recall  f1-score   support
#
# Negative (0)     0.8231    0.6310    0.7144      2087
# Positive (1)     0.8574    0.9424    0.8979      4913
#
#     accuracy                         0.8496      7000
#    macro avg     0.8403    0.7867    0.8061      7000
# weighted avg     0.8472    0.8496    0.8432      7000
#
#
# --- 2. TEST SET Evaluation ---
#               precision    recall  f1-score   support
#
# Negative (0)     0.6502    0.5157    0.5752       894
# Positive (1)     0.8110    0.8822    0.8451      2106
#
#     accuracy                         0.7730      3000
# ...

# %%
from sklearn.linear_model import LogisticRegression

param_grid_logreg = {
    'C': [0.1, 1.0, 5.0, 10.0]  # Test different regularization strengths
}

models_to_test = {
    "LogisticRegression": (LogisticRegression(C=1.0, max_iter=1000, random_state=42),
                           param_grid_logreg),
}


print("Running experiments with LogisticRegression...")
run_model_experiments_with_gridsearch(vectorized_data_store, models_to_test)
# Out:
# Running experiments with LogisticRegression...
#
# --- Starting: Running all model experiments with GridSearch ---
#
# ...
# MODEL: LogisticRegression   |   DATASET: clean_tokens__(1, 1)
# ...
# Using GridSearchCV for hyperparameter tuning...
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
#
# --- 1. TRAINING SET Evaluation ---
#               precision    recall  f1-score   support
#
# Negative (0)     0.9620    0.8979    0.9289      2087
# Positive (1)     0.9578    0.9849    0.9712      4913
#
#     accuracy                         0.9590      7000
#    macro avg     0.9599    0.9414    0.9500      7000
# weighted avg     0.9591    0.9590    0.9586      7000
#
#
# --- 2. TEST SET Evaluation ---
#               precision    recall  f1-score   support
#
# Negative (0)     0.8443    0.7159    0.7748       894
# Positive (1)     0.8867    0.9440    0.9144      2106
#
#     accuracy                         0.8760      3000
#    macro avg     0.8655    0.8299    0.8446      3000
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

models_to_test = {
    "KNN5": (KNeighborsClassifier(n_neighbors=5, n_jobs=-1),
             None),
    "KNN3": (KNeighborsClassifier(n_neighbors=3, n_jobs=-1),
             None),
}

print("Running experiments with KNN...")
run_model_experiments_with_gridsearch(vectorized_data_store, models_to_test)
# Out:
# Running experiments with KNN...
#
# --- Starting: Running all model experiments with GridSearch ---
#
# ...
# MODEL: KNN5   |   DATASET: clean_tokens__(1, 1)
# ...
# Training model without GridSearch...
#
# --- 1. TRAINING SET Evaluation ---
#               precision    recall  f1-score   support
#
# Negative (0)     0.7737    0.6766    0.7219      2087
# Positive (1)     0.8696    0.9159    0.8921      4913
#
#     accuracy                         0.8446      7000
#    macro avg     0.8216    0.7963    0.8070      7000
# weighted avg     0.8410    0.8446    0.8414      7000
#
#
# --- 2. TEST SET Evaluation ---
#               precision    recall  f1-score   support
#
# Negative (0)     0.6224    0.5291    0.5719       894
# Positive (1)     0.8121    0.8637    0.8371      2106
#
#     accuracy                         0.7640      3000
#    macro avg     0.7172    0.6964    0.7045      3000
# weighted avg     0.7555    0.7640    0.7581      3000
#
#
# Training & Prediction Time: 6.03 seconds
# ...
#
#
# ...

# %%
# --- 1. Import the models ---
from sklearn.naive_bayes import MultinomialNB, ComplementNB, BernoulliNB

# --- 2. Define the models you want to try ---

param_grid_cnb = {
    'alpha': [0.1, 0.5, 1.0]  # Test different smoothing values
}
# We'll give them clear names to see the difference in the report
models_to_test = {
    "Naive_Bayes_Multinomial": (MultinomialNB(),
     param_grid_cnb),
    "Naive_Bayes_Complement": (ComplementNB(),
     param_grid_cnb),
    "Naive_Bayes_Bernoulli": (BernoulliNB(),
     param_grid_cnb),
}

# --- 3. Run the experiments ---
# Your 'vectorized_data_store' should still be in memory
print("Running experiments with all three Naive Bayes variants...")
run_model_experiments_with_gridsearch(vectorized_data_store, models_to_test)
# Out:
# Running experiments with all three Naive Bayes variants...
#
# --- Starting: Running all model experiments with GridSearch ---
#
# ...
# MODEL: Naive_Bayes_Multinomial   |   DATASET: clean_tokens__(1, 1)
# ...
# Using GridSearchCV for hyperparameter tuning...
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
#
# --- 1. TRAINING SET Evaluation ---
#               precision    recall  f1-score   support
#
# Negative (0)     0.9397    0.6866    0.7935      2087
# Positive (1)     0.8805    0.9813    0.9282      4913
#
#     accuracy                         0.8934      7000
#    macro avg     0.9101    0.8340    0.8608      7000
# weighted avg     0.8982    0.8934    0.8880      7000
#
#
# --- 2. TEST SET Evaluation ---
#               precision    recall  f1-score   support
#
# Negative (0)     0.9117    0.5425    0.6802       894
# Positive (1)     0.8343    0.9777    0.9003      2106
#
#     accuracy                         0.8480      3000
# ...

# %%
# --- 1. Import the models ---
from sklearn.svm import LinearSVC, SVC
from sklearn.linear_model import SGDClassifier

# --- 2. Define the models you want to try ---
param_grid_svc = {
    'C': [0.1, 1.0, 5.0, 10.0]  # Test different regularization strengths
}

models_to_test = {
    "SVM_LinearSVC": (LinearSVC(random_state=42),param_grid_svc),
    "SVM_SGDClassifier_Hinge": (SGDClassifier(loss='hinge', random_state=42, n_jobs=-1),None),
    "SVM_SVC_rbf_Kernel": (SVC(kernel='rbf', random_state=42),param_grid_svc),
}

# --- 3. Run the experiments ---
# Your 'vectorized_data_store' should still be in memory
print("Running experiments with SVM variants...")
run_model_experiments_with_gridsearch(vectorized_data_store, models_to_test)
# Out:
# Running experiments with SVM variants...
#
# --- Starting: Running all model experiments with GridSearch ---
#
# ...
# MODEL: SVM_LinearSVC   |   DATASET: clean_tokens__(1, 1)
# ...
# Using GridSearchCV for hyperparameter tuning...
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
#
# --- 1. TRAINING SET Evaluation ---
#               precision    recall  f1-score   support
#
# Negative (0)     0.9811    0.9454    0.9629      2087
# Positive (1)     0.9771    0.9923    0.9846      4913
#
#     accuracy                         0.9783      7000
#    macro avg     0.9791    0.9688    0.9738      7000
# weighted avg     0.9783    0.9783    0.9782      7000
#
#
# --- 2. TEST SET Evaluation ---
#               precision    recall  f1-score   support
#
# Negative (0)     0.8207    0.7170    0.7654       894
# Positive (1)     0.8860    0.9335    0.9091      2106
#
#     accuracy                         0.8690      3000
#    macro avg     0.8534    0.8253    0.8373      3000
# ...

# %%
# --- 1. Import the model ---
from sklearn.neural_network import MLPClassifier

param_grid_mlp = {
    'hidden_layer_sizes': [(100,), (100, 50)],  # Test one layer vs. two layers
    'activation': ['relu'],                    # ReLU is the most common default
    'alpha': [0.0001, 0.001]                   # Test two different regularization strengths
}

# --- 2. Define the models you want to try ---
# Let's try one hidden layer of 100 neurons, and another with two layers (100, then 50)
models_to_test = {
    "MLP_Classifier_Tuned": (
        MLPClassifier(max_iter=500, random_state=42, early_stopping=True),
        param_grid_mlp
    ),
}

# --- 3. Run the experiments ---
# Your 'vectorized_data_store' should still be in memory
print("Running experiments with Neural Networks (MLPClassifier)...")
run_model_experiments_with_gridsearch(vectorized_data_store, models_to_test)
# Out:
# Running experiments with Neural Networks (MLPClassifier)...
#
# --- Starting: Running all model experiments with GridSearch ---
#
# ...
# MODEL: MLP_Classifier_Tuned   |   DATASET: clean_tokens__(1, 1)
# ...
# Using GridSearchCV for hyperparameter tuning...
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
#
# --- 1. TRAINING SET Evaluation ---
#               precision    recall  f1-score   support
#
# Negative (0)     0.9498    0.9066    0.9277      2087
# Positive (1)     0.9611    0.9796    0.9703      4913
#
#     accuracy                         0.9579      7000
#    macro avg     0.9554    0.9431    0.9490      7000
# weighted avg     0.9577    0.9579    0.9576      7000
#
#
# --- 2. TEST SET Evaluation ---
#               precision    recall  f1-score   support
#
# Negative (0)     0.8474    0.7204    0.7787       894
# Positive (1)     0.8884    0.9449    0.9158      2106
#
#     accuracy                         0.8780      3000
# ...

# %%
from owlready2 import *
import re

# 1. Create a new ontology (like in the lab)
onto = get_ontology("http://example.org/hotel_reviews.owl")

with onto:
    # --- 1. Define Concepts (Classes) ---
    # We define the high-level concepts
    class HotelAspect(Thing): pass
    class Sentiment(Thing): pass
    class Review(Thing): pass
    
    # Define specific aspects
    class Room(HotelAspect): pass
    class Staff(HotelAspect): pass
    class Food(HotelAspect): pass
    class Service(HotelAspect): pass
    class Location(HotelAspect): pass
    
    # Define specific sentiments
    class Positive(Sentiment): pass
    class Negative(Sentiment): pass
    class Neutral(Sentiment): pass

    # --- 2. Define Relationships (Properties) ---
    class mentions_aspect(ObjectProperty):
        domain = [Review]
        range = [HotelAspect]

    class has_sentiment(ObjectProperty):
        # A review can have an overall sentiment
        domain = [Review]
        range = [Sentiment]
        
    class is_described_by(ObjectProperty):
        # An aspect within a review can have a sentiment
        domain = [HotelAspect]
        range = [Sentiment]
        
    class has_text(DataProperty):
        domain = [Review]
        range = [str]

print("Hotel Ontology structure defined successfully.")
onto.save(file = "hotel_ontology.owl", format = "rdfxml")
# Out:
# Hotel Ontology structure defined successfully.
# ...

# %%
# --- 1. Define simple lexicons (our rules) ---
# These are your "rules that already exist" as simple dictionaries
ASPECT_KEYWORDS = {
    "Room": ["room", "bed", "bathroom", "shower", "ac", "sheets"],
    "Staff": ["staff", "manager", "reception", "concierge", "valet", "desk clerk"],
    "Food": ["food", "breakfast", "restaurant", "coffee", "dinner", "meal"],
    "Service": ["service", "check-in", "checkout", "booking", "housekeeping"],
    "Location": ["location", "view", "area", "neighborhood", "walk"]
}

# --- 2. Load the ontology and VADER ---
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
onto = get_ontology("hotel_ontology.owl").load()

# --- 3. Populate the Ontology with your DataFrame ---
with onto:
    # Loop through the first 50 reviews in your DataFrame (df)
    for index, row in df.head(50).iterrows():
        
        # Create a new "Individual" for this review
        review_id = f"Review_{row['review_id']}"
        new_review = Review(review_id)
        
        # Add the text as a property
        new_review.has_text.append(row['text'])
        
        # Rule 1: Assign overall sentiment using VADER
        vader_score = analyzer.polarity_scores(row['text'])['compound']
        if vader_score >= 0.05:
            new_review.has_sentiment.append(Positive("OverallPositive"))
        elif vader_score <= -0.05:
            new_review.has_sentiment.append(Negative("OverallNegative"))
        else:
            new_review.has_sentiment.append(Neutral("OverallNeutral"))
            
        # Rule 2: Find mentioned aspects
        review_text_lower = row['text'].lower()
        for aspect_name, keywords in ASPECT_KEYWORDS.items():
            if any(re.search(r'\b' + re.escape(keyword) + r'\b', review_text_lower) for keyword in keywords):
                
                # Get the class from the ontology (e.g., onto.Room)
                AspectClass = getattr(onto, aspect_name)
                
                # Create a new "Individual" for this aspect *in this review*
                # e.g., "Room_in_Review_123"
                aspect_individual = AspectClass(f"{aspect_name}_in_{review_id}")
                
                # Link the review to this aspect
                new_review.mentions_aspect.append(aspect_individual)

print(f"Successfully populated the ontology with {len(list(onto.Review.instances()))} reviews.")

# --- 4. Save the populated ontology ---
onto.save(file = "hotel_ontology_populated.owl", format = "rdfxml")
# Out:
# Successfully populated the ontology with 50 reviews.

# %%
# --- Example Queries (like the lab) ---

print("--- Querying the Ontology ---")

# 1. Find all reviews that mention 'Room'
room_reviews = []
for review in onto.Review.instances():
    for aspect in review.mentions_aspect:
        if isinstance(aspect, onto.Room):
            room_reviews.append(review.name)
print(f"Found {len(room_reviews)} reviews that mention 'Room':\n{room_reviews}\n")


# 2. Find all reviews that are 'OverallNegative'
negative_reviews = []
for review in onto.Review.instances():
    for sentiment in review.has_sentiment:
        if isinstance(sentiment, onto.Negative):
            negative_reviews.append(review.name)
print(f"Found {len(negative_reviews)} negative reviews:\n{negative_reviews}\n")


# 3. Find all negative reviews that mention 'Staff'
neg_staff_reviews = []
for review in onto.Review.instances():
    is_negative = any(isinstance(s, onto.Negative) for s in review.has_sentiment)
    mentions_staff = any(isinstance(a, onto.Staff) for a in review.mentions_aspect)
    
    if is_negative and mentions_staff:
        neg_staff_reviews.append(review.name)
        
print(f"Found {len(neg_staff_reviews)} reviews that are BOTH negative AND mention staff:\n{neg_staff_reviews}")
# Out:
# --- Querying the Ontology ---
# Found 4 reviews that mention 'Room':
# ['Review_6AxgBCNX_PNTOxmbRSwcKQ', 'Review_pHwbdway4yeI-dSSmZA7-Q', 'Review_YcLXh-3UC9y6YFAI9xxzPQ', 'Review_ra9fNjYUumKp_iaqv-jjDg']
#
# Found 3 negative reviews:
# ['Review_ZKvDG2sBvHVdF5oBNUOpAQ', 'Review_z0osLHDvXvzfm57D4DmD2Q', 'Review_RB8UpF_kT2xoOC51OzXEeA']
#
# Found 1 reviews that are BOTH negative AND mention staff:
# ['Review_ZKvDG2sBvHVdF5oBNUOpAQ']

# %%
# --- 1. Install graphviz (if you haven't already) ---
# !pip install graphviz

import graphviz
from owlready2 import *

# --- 2. Load your ontology STRUCTURE ---
# We load the unpopulated file (hotel_ontology.owl) to see the rules, not the 50 facts.
try:
    onto = get_ontology("hotel_ontology.owl").load()
except FileNotFoundError:
    print("Error: 'hotel_ontology.owl' not found. Please re-run Cell 33 to create it.")
    # Handle the error gracefully if the file doesn't exist

# --- 3. Create the graph ---
dot = graphviz.Digraph(comment='Hotel Review Ontology Structure')
dot.attr(rankdir='BT') # Arrange graph from Bottom-to-Top (cleaner hierarchy)

# --- 4. Add Classes as nodes ---
for cls in onto.classes():
    if cls is not Thing: # Don't show the default "Thing" root
        dot.node(cls.name, cls.name, shape='ellipse', style='filled', color='lightblue')

# --- 5. Add Class 'is_a' relationships (e.g., Room -> HotelAspect) ---
for cls in onto.classes():
    for super_cls in cls.is_a:
        # Check if it's a defined class in our ontology, not a base property
        if isinstance(super_cls, ThingClass) and super_cls is not Thing:
            dot.edge(cls.name, super_cls.name, label="is_a")

# --- 6. Add Property relationships (the rules) ---
for prop in onto.object_properties():
    # Get the domain and range for the property
    domain_names = [d.name for d in prop.domain if d is not Thing]
    range_names = [r.name for r in prop.range if r is not Thing]
    
    # Draw an edge for each domain/range pair
    for d_name in domain_names:
        for r_name in range_names:
            dot.edge(d_name, r_name, label=prop.name, color='red', style='dashed', fontsize='10')

# --- 7. Save and display the graph ---
try:
    dot.render('hotel_ontology_structure', format='png', view=True)
    print("Graph 'hotel_ontology_structure.png' created successfully!")
    # In some notebooks, you might need this to display it inline:
    # from IPython.display import Image
    # display(Image('hotel_ontology_structure.png'))
except Exception as e:
    print(f"Error rendering graph. Make sure Graphviz is installed and in your system's PATH. Error: {e}")

dot
# Out:
# Error rendering graph. Make sure Graphviz is installed and in your system's PATH. Error: failed to execute WindowsPath('dot'), make sure the Graphviz executables are on your systems' PATH
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\graphviz\backend\execute.py:76, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      75         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 76     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      77 else:
#
# File ~\anaconda3\Lib\site-packages\graphviz\backend\execute.py:96, in _run_input_lines(cmd, input_lines, kwargs)
#      95 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 96     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#      98     stdin_write = popen.stdin.write
#
# ...
